# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh3146/classification_projects/blob/main/wine_quality_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/WineQT.csv')

# %%
df = df.drop(['Id'],axis = 1)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X = df.loc[:,:]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
X = X.drop(['quality'],axis = 1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
Y = df['quality']

# %%
Y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.30)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC = RandomForestClassifier(n_estimators=100)

# %%
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predicted_values = RFC.predict(x_test)

# %%
actual_values = y_test

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(actual_values,predicted_values)

# %%
matrix
# Out:
# array([[  0,   0,   1,   0,   0,   0],
#        [  0,   0,   6,   1,   0,   0],
#        [  0,   0, 112,  42,   0,   0],
#        [  0,   0,  27, 100,   4,   0],
#        [  0,   0,   1,  26,  19,   0],
#        [  0,   0,   0,   1,   3,   0]])

# %%
from sklearn.metrics import accuracy_score

# %%
print("accuracy of model :",accuracy_score(actual_values,predicted_values))
# Out:
# accuracy of model : 0.673469387755102

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d = DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_results = d.predict(x_test)

# %%
print('accuracy score : ',accuracy_score(y_test,predicted_results))
# Out:
# accuracy score :  0.5335276967930029

# %%
from sklearn.linear_model  import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
predicted_values2 = lg.predict(x_test)

# %%
print("accuracy_score :",accuracy_score(y_test,predicted_values2))
# Out:
# accuracy_score : 0.5918367346938775

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
predicted_value3 = gbc.predict(x_test)

# %%
print("accuracy :",accuracy_score(y_test,predicted_value3))
# Out:
# accuracy : 0.6268221574344023

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adc = AdaBoostClassifier()

# %%
adc.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
predicted_value4 = adc.predict(x_test)

# %%
print("accuracy :",accuracy_score(y_test,predicted_value4))
# Out:
# accuracy : 0.5189504373177842

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
predicted_values5 = svc.predict(x_test)

# %%
print("accuracy score :",accuracy_score(y_test,predicted_values5))
# Out:
# accuracy score : 0.5014577259475219

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()

# %%
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
predicted_values6 = mnb.predict(x_test)

# %%
print("accuracy score :",accuracy_score(y_test,predicted_values6))
# Out:
# accuracy score : 0.4227405247813411

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc = KNeighborsClassifier()

# %%
knc.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predicted_values7 = knc.predict(x_test)

# %%
print("accuracy score :",accuracy_score(y_test,predicted_values7))
# Out:
# accuracy score : 0.5043731778425656

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier()

# %%
mlp.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPClassifier()

# %%
predicted_values8 = mlp.predict(x_test)

# %%
print("accuracy :",accuracy_score(y_test,predicted_values8))
# Out:
# accuracy : 0.597667638483965
